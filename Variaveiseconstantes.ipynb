# %% [markdown]
# <a href="https://colab.research.google.com/github/JheanSantanaM/PA_2025/blob/main/Variaveiseconstantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #variaveis e constantes

# %%
idade = 15
altura = 1.80
nome = 'jhean'
vai = True

# %%
nomes = ['Jhean','juninho','davi','flavio']
nomes2 = ('Jhean','juninho','davi','flavio')
tudo = {nome:'jhean',idade: 15,altura: 1.80,vai: True}

# %%
print(nome)
print(nomes)
print(nomes2)
# Out:
# jhean
# ['Jhean', 'juninho', 'davi', 'flavio']
# ('Jhean', 'juninho', 'davi', 'flavio')

# %%
print(type(idade))
print(type(altura))
print(type(vai))
print(type(nome))
print(type(nomes))
print(type(nomes2))
print(type(tudo))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
print('o nome dele é:',nome,', sua idade é: ' , idade, ', ele tem ' , altura, 'metros de altura.')
# Out:
# o nome dele é: jhean , sua idade é:  15 , ele tem  1.8 metros de altura.

# %%
Nome2 = "kleber"
idade2 = 15
print(f"nome: {Nome2}, idade: {idade2}")
# Out:
# nome: kleber, idade: 15

# %% [markdown]
# #Area do circulo

# %%
PI = 3.14159
raio = float(input('Digite o valor do raio do circulo'))
areacir = PI * (raio**2)
print(f"A area do circulo é {areacir}")
# Out:
# Digite o valor do raio do circulo5
# A area do circulo é 78.53975

# %% [markdown]
# # Area do quadrado

# %%
Lado = float(input('digite a area do quadrado:'))
areaqua = Lado ** 2
print(f'area do quadrado: {areaqua}')
# Out:
# digite a area do quadrado:4
# area do quadrado: 16.0

# %% [markdown]
# #Exercícios

# %% [markdown]
# ##Exercício 1 - Área do Retângulo
#
# Crie um programa que calcule a área de um retângulo usando uma constante para representar a base.
#
#  Fórmula: A = base × altura

# %%
base = float(input('digite a base do retangulo:'))
alturaret = float(input('digite a altura do retangulo:'))
resultado = base * alturaret
print(f'a area do retangulo é: {resultado}')
# Out:
# digite a base do retangulo:8
# digite a altura do retangulo:6
# a area do retangulo é: 48.0

# %% [markdown]
# ##Exercício 2 – Perímetro do Círculo
#
# Crie um programa que calcule o perímetro de um círculo usando a constante π.
#
#  Fórmula: P = 2 × π × r

# %%
PI = 3.14159
raio2 = float(input('digite o raio do circulo:'))
resultado2 = P = 2 * 3.14159 * raio2
print(f'o perimetro do circulo é: {resultado2:.2f}')
# Out:
# digite o raio do circulo:7
# o perimetro do circulo é: 43.98

# %% [markdown]
# ##Exercício 3 – Conversão de Temperatura
#
# Crie um programa que converta uma temperatura de Fahrenheit para Celsius.
#
#  Fórmula: C = (F - 32) × 5/9

# %%
fahrenheit = float(input('digite a temperatura em fahrenheit:'))
resultado3 = C = (fahrenheit - 32) * 5/9
print(f'Esse fahrenheit em celcius é:{resultado3:.2f}')
# Out:
# digite a temperatura em fahrenheit:23

# %% [markdown]
# ##Exercício 4 – Cálculo do IMC
#
# Crie um programa que calcule o Índice de Massa Corporal (IMC) de uma pessoa.
#
#  Fórmula: IMC = peso / altura²

# %%
peso = float(input('Digite seu peso:'))
altura = float(input('digite sua altura:'))
resultado4 = IMC = peso / altura**2
print(f'o seu IMC é: {resultado4:.2f}')
# Out:
# Digite seu peso:75
# digite sua altura:1.80
# o seu IMC é: 23.15

# %% [markdown]
# #Cálculo de Média
#
# Um fluxograma pode representar o processo de cálculo da média de duas notas, mostrando as etapas de entrada das notas, a operação de soma e a divisão por 2 para obter a média.
#
# ![image.png](data:image/png;base64,...)

# %%
num1 = float(input("digite um numero: "))
num2 = float(input("digite outro numero: "))
media = (num1+num2)/2
print(media)
# Out:
# digite um numero: 5
# digite outro numero: 8
# 6.5

# %% [markdown]
# #Conversão de Moeda
#
# Outro exemplo é a conversão de moeda. O fluxograma ilustra as etapas de receber a cotação do dólar, o valor em reais e a divisão para obter o valor em dólares.
#
# ![image.png](data:image/png;base64,...)

# %%
cotacao = float(input("digite a cotação: "))
valorreais = float(input("digite o valor em reais: "))
resultado = (valorreais/cotacao)
print(f"o resultado dessa cotação em reias é: {resultado:.2f}")
# Out:
# digite a cotação: 5.18
# digite o valor em reais: 80
# o resultado dessa cotação em reias é: 15.44

# %% [markdown]
# #Cálculo de Comissão
#
# O cálculo de comissão pode ser facilmente representado por um fluxograma, mostrando as etapas de receber o preço unitário, a quantidade vendida e o cálculo da comissão.
#
# ![image.png](data:image/png;base64,...)

# %%
valor = float(input('Digite um valor:'))
quantidade = float(input('Digite a quantidade: '))
venda = valor*quantidade
comissao = (venda * 5) / 100
print(comissao)
# Out:
# Digite um valor:9
# Digite a quantidade: 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-d0b3441bbad9> in <cell line: 0>()
#       3 venda = valor*quantidade
#       4 comissao = (venda * 5) / 100
# ----> 5 print(comissao)
#
# TypeError: 'float' object is not callable

# %% [markdown]
#  1) custo ao consumidor de um carro novo é a soma do custo de fábrica com a percentagem do distribuidor e dos impostos (aplicados, primeiro os impostos sobre o custo de fábrica, e depois a percentagem do distribuidor sobre o resultado). Supondo que a percentagem do distribuidor seja de 28% e os impostos 45%. Escrever um algoritmo que leia o custo de fábrica de um carro e informe o custo ao consumidor do mesmo.
#
# ![image.png](data:image/png;base64,...)

# %%
imposto = float(input("Digite um imposto: "))
carro  = float(input("Digite o valor do carro: "))
imposto = (carro * 45/100) + 100
valor = (imposto * 28/100) + carro
print(valor)
# Out:
# Digite um imposto: 20
# Digite o valor do carro: 100000
# 112628.0

# %% [markdown]
# 2) Faça um algoritmo que faça conversão de minutos e horas em segundos. Solicite ao usuário a hora e os minutos separado.
#
# ![image.png](data:image/png;base64,...)

# %%
hora = int(input("Digite a hora: "))
minuto = int(input("Digite o minuto: "))
valor = hora + (minuto/60)
print(f"O horario é {valor}:")
# Out:
# Digite a hora: 3
# Digite o minuto: 3

# %% [markdown]
# 3)  Continuando do exercício anterior, um funcionário trabalha em determinada empresa e quer saber quanto irá ganhar de hora extra. Você deverá fazer um algoritmo que solicite quantas horas e quantos minutos ele trabalhou, solicite horas e minutos de forma separada. Depois pergunte quanto ele ganha por hora e informe quanto ele irá ganhar. Sabendo que nessa empresa o funcionário ganha 70% a mais pelas horas trabalhadas.
#
# ![image.png](data:image/png;base64,...)

# %%
hora = float(input("Digite as horas trabalhadas: "))
minutos = float(input("Digite os minutos trabalhados: "))
ganhohora = float(input("Digite o seu ganho por hora: "))
valor = hora + (minuto/60)
salario = valor * ganhohora
valorfinal = (salario * 70/100) + salario
print(valorfinal)
# Out:
# Digite as horas trabalhadas: 80
# Digite os minutos trabalhados: 5
# Digite o seu ganho por hora: 5

# %% [markdown]
# 4) Simulação de Investimento em CDB com Juros Compostos
#
# Uma pessoa deseja investir um valor em um CDB que rende uma taxa fixa de X% ao ano. Escreva um algoritmo que solicite o valor inicial do investimento, a taxa de juros anual (em %) e o período em anos. Depois, calcule o montante final considerando juros compostos.
#
# ![image.png](data:image/png;base64,...)

# %%
valorinicial = float(input("Digite o valor inicial:: "))
taxajuros = float(input("Digite a taxa de juros: "))
periodoano = float(input("Digite o periodo: "))
mont = valorinicial * (1 + taxajuros) ** periodoano
print(mont)
# Out:
# Digite o valor inicial:: 1000
# Digite a taxa de juros: 0.06
# Digite o periodo: 5

# %% [markdown]
# 5) Divisão de Conta em um Restaurante com Gorjeta
#
# Um grupo de amigos foi a um restaurante e deseja dividir a conta igualmente entre eles. Além disso, o restaurante cobra uma taxa de serviço de 10% sobre o valor total da conta mais uma gorjeta.
#
# Escreva um algoritmo que solicite o valor da conta e o número de pessoas no grupo. Depois, calcule o valor total com a taxa de serviço e quanto cada pessoa deve pagar.
#
#
# ![image.png](data:image/png;base64,...)

# %%
conta = float(input("Digite o valor da conta: "))
pessoas = int(input("Digite o numero de pessoas: "))
gorjeta = float(input("Digite o valor da gorjeta: "))
taxaserv = (conta * 10/100) + conta
total = taxaserv + gorjeta
resultado = total/pessoas
print(resultado)
